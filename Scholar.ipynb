# %% [markdown]
# # How-to:
#     - Start Institutional VPN
#     - Change variables: Location (where do you want to download to?), PATH (where is chromedriver installed?), query, Start and year
#     - run the cell below
#     - (optional) Download the result

# %%
#import scraper_tobiashilt as scrape 
import scraper_tobiashilt as scrape
from datetime import datetime
Date = datetime.today().strftime('%Y-%m-%d')

#Location where the results should be downloaded to
Location = '/Users/Tobias/Desktop/Python/'


# Local path to your chromedriver
PATH = '/Applications/chromedriver'

# Search string
query = '("DLT" OR "Distributed Ledger") AND ("Circular Economy" OR "Sustainable supply chain")'

#Beginning of Search (year)
Start = 2019

#Number of results
count = 22

# %%
df_scholar = scrape.scrape_scholar(query, PATH, Start, count)
df_scholar
# Out:
# Seitenanzahl der Scholar-Suche: 3
# Insgesamte Anzahl an Ergebnissen bei Google Scholar: 1580
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
# ---
#     DOI                                              Title  \
# 1   NaN  Using internet of things and distributed ledge...
# 2   NaN  A blockchain-based approach for a multi-echelo...
# 3   NaN  Circularity for Electric and Electronic Equipm...
# 4   NaN  Demand-supply matching through auctioning for ...
# 5   NaN  Blockchain and Artificial Intelligence Managin...
# 6   NaN  eReuse poster: the circular economy of digital...
# 7   NaN   Blockchain adoption in the fashion sustainabl...
# 8   NaN  Blockchain technology and the circular economy...
# 9   NaN  Sustainable supply chain management: potential...
# 10  NaN   Reimagining new socio-technical economics thr...
# 11  NaN  Using internet of things and distributed ledge...
# 12  NaN  A blockchain-based approach for a multi-echelo...
# ...

# %% [markdown]
# ## Download

# %%
excel_scholar = Location + Date + "_scholar.xlsx"
df_scholar.to_excel(excel_scholar)
